# %% [markdown]
# <a href="https://colab.research.google.com/github/ankit1993-cmd/basics-of-python/blob/main/oops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # oops assignment
#
# 1. what is object-oriented programming
#
# - object-oriented programming paradigm that focuses on the conceptof objects,which can contain data (fields,attribute,properties) and have actiion they can perform (procedures or methods) implemented in code.
#
# 2. what is a class in oop.
#
# - in oop , a class is a blueprint or template for creating object(instances).
#
# 3. what is an object in oop.
#
# - in oop, an object is a fundamental component that represent a real world entity or concept.
#
# 4. what is difference between abstraction and encapsulation.
#
# - encapsulation hides variable or some implimentation that may be changed so often in a class to prevent outsiders access it directly. they must access it via getter and setter method.
# abstraction is used to hide something too, but in a higher degree(class,interface). clients who use an abstract class do not care about what it was ,they just need to know what it can do.
#
# 5. what are dunder methon in python.
#
# - dunder methods, also known as magic methods or speicel methods, are predefined methods in python that have double underscores(or "dunders") at the beginning and end of their names.
#
# 6. explain the concept of inheritance in oop.
#
# - inheritance in python object-oriented programming is a mechanism that allows a class to inherit attributes and methods from another class(called a parent or base class).
#
# 7. what is polymorphism in oop.
#
# - polymorphism in oop is the ability of an object to take on many forms.
# it allows method to be written to work with objects of different classes, which can be treated as instances of a commom superclass. this is commonly achived through inheritance,where a child class can override methods of its parent class enabling different behaviour based on the specific object type.
#
# 8. how is encapsulation achived in python.
#
# - encapsulation in python is achived through the use of access modifiers and getter and setter methods.
# variable and methods in python can be made private,protected,or public although python does not enforce these access levels strictly. instead it relies on naming convention : private variables and methods are prefixed with double underscore (_) protected variable and methods are prefixed with a single underscore (_) and public variable and methods do not have any special prefix.
#
# 9. what is a constructor in python .
#
# - in python, a constructor is a speicel method named _init_ that is called automatically when an object is created from a class . it is used to intilized the object's attributes or state setting up it intial values.
#
# 10. what are class and static method in python.
#
# - in python, class methods and static methods are both defined within a class but serve different purposes and have distinct characterstics.
# a class method is a method that is bound to the class itself,defined with the @classmethod decorator. it receives cls as the first argument,representing the class,and can access and modified class level data . class methods are often are used for operations that modify or interact with class level data, such as factory method that return class object for different use casees.
# a static method ,on the other hand ,is defined with the @staticmethod decorator and does not receive an implicit first argument(self or cls). static method can not access or modify class or instance attributes. they are typically used for utility functions that don't depend on the state of object such as formatting dates or performing mathematically operation.
#
# 11. what is method overloading in python.
#
# - method overloading in python refers to the ability to define multiple methods with the same name but different parameter in a class . however, python does not directly support method overloading like some other languages like jave or c++. instead developers can simulate method overloading by using default arguments,variable length arguments(*args,**kwargs) or condition logic within a single method.
#
# 12. what is method overriding in oop.
#
# - method overriding in oop occurs when a child classdefines a methods with a same name and parameters as a method in its parent class,allowing the child class to provide a specific implementaion of that method.
#
# 13. what is a property decorator in python.
#
# - in python, the property decorator is a built in decorator that allows you to define methods as a properties of class.this means you can access these methods as if the were attributes,without needing to call them as function.
#
# 14. why is polymorphism important in oop.
#
# -  polymorphism in python oop allows objects of different classes to be treated
#    interchangeably if they share method names,promoting code flexibility and reuseability. it simplifies maintaining and extending code by letting you write generic functions that work with multiple types,reduce redundency, and aligns with python's dynamic,readable design.for example, a speak() method in dog and cat classes can be called uniformly, avoiding rigid type checks. this makes systems modular and adaptable.
#
# 15. what is abstract class in python.
#
# - in python, an abstract class is a class that can not be instantiated and contains one or more abstract methods without defined implementation. abstract classes provide a blueprint for other classes,enforcing a common structure while allowing derived classes to provide concrete implimentaion for the abstract methods.
#
# 16. what are advantages of oop.
#
# - resusability: inhert/extend classes to reuse code.
# - modularity: break code into organized,manageble classes.
# - encapsulation: protect data via private attributes/methods.
# - polymorphism: flexible method behavior accross objects.
# - abstraction: simplify complexity with high level interfaces.
# - maintainability: easier to debug and update structured code.
# - readability: model real world logic intuitively.
#
# 17. what is the difference between a class variable and an instance variable.
#
# - in python, a class variable is defined at the class level and shared among all instances of the class ,whereas an instance variable is defined within methods and is specific to each instance of the class.
#
# 18. what is multiple inheritance in python.
#
# - multiple inheritance in python is a feature where a class can inherit attributes and methods for more than one parent class. this allows a child class to combine behaviours or attributes from multiple other classes,which can be quite powerful. for example,if you have a video class and a audio class,you can create a multimedia class that inherits from both ,combining their functionalitis.
#
# 19. explain the purpose of " --str--'and'--repr--" methods in python.
#
# - in python, the --str-- methods is used to provide a human-readable string representaion of an object,intended for display to users, it is called automatically when the object is printed or passed to the str() function.
# on the other hand, the --repr-- method is used to provide an unambiguous string representaion of an object,typically for debugging or logging purposes.this method returns
#
# 20.what is significance of the super() function in python.
#
# - the super() function in python significant because it allows a subclass toherit and extend the behaviour of its parent class while providing flexibility to override or extend that behavior in the subclass.
#
# 21. what is significance of the __del__ method in python.
#
# - the __del__ method in python is a destructor method that is called when an object is about to be destroyed. it allows you to define specific cleanup actions that should be taken when an object is garbage collected, such as closing files,releasing locks,or closing network connections.
#
# 22. what is the difference between @staticmethod and @classmethod in python.
#
# - decorator: @staticmethod is used to define a static method,while @classmethod is used to define a class method.
# -first arguments: @staticmethod does not receive any implicit first argument,whereas @classmethod receives the class itself (cls) as the first argument.
# -access: @staticmethod can only access class-level attributes and other static methods,but not instance-level attributes. @classmethod can access class-level attributes and other class methods,but not instance level attributes.
#
# 23. how does polymorphism work in python with inheritance.
#
# - in python,polymorphism with inhertance allows child classes to override parent methods.when a method is called on an object,python uses the method from the object's class if defined,otherwise,it uses the parent's. this enables different classes to share the same method name with varying implementation.
#
# 24. what is method chaining in python oop.
#
# - method chaining in python is a technique used in object-oriented programming where multiple methods of same object are called in succession,each method returning the object itself to allow further method calls to be chained together.this pattern enhances code readability and conciseness by eliminating the need for inter midiate variable or repeated methods call.
#
# 25. what is the purpose of the __call__method in python.
#
# -in python,the __call__ method allows instances of a class to be called like functions. when defined, calling an object using parentheses triggers the __call__ method,enabling more flexible and reuseable code.this method can take arguments and return values,and it can also cause side effects,making the instances of the class behaver like functions.

# %% [markdown]
# # oops practical

# %%
#1. create a parent class animal with method speak() that prints generic message.create a child class dog that overrides the speak() method to print "bark".
class Animal:
  def speak(self):
    print("the animal makes a sound")
    class Dog(Animal):
      def speak(self):
        print("bark")

#2. write a program to create an abstract class shape with a method area().derive classes circle and rectangle from it and implement the area() method in both.
from abc import ABC,abstractmethod import math
class Shape(ABC):
  @abstractmethod
  def area(self):
    pass
    class Circle(Shape):
      def__init__(self,radius):
        self.radius = radius
        def area(self):
          return math.pi * self.radius ** 2
          class Rectangle(Shape):
            def__init__(self,width,height):
              self.width = width
              self.height = height
              def area(self):
                return self.width * self.height

#3. implement a multi-level inhertance scenario where a class vehicle has an attribute type.derive a class car and further derive a class electriccar that adds a battery attribute.
class Vehicle:
  def__init__(self,type):
    self.type = type
    class Car(Vehicle):
      def__init__(self,type):
        super().__init__(type):
        class ElectricCar(car):
          def__init__(self,type,battery):
            super().__init__(typr)
            self.battery = battery

#4. demonstrate polymorphism by creating a base class bird with a method fly().create two derived classes sparrow and penguin that override the fly()method.
class Bird:
    def fly(self):
        print("This bird can fly")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies swiftly through the air")

class Penguin(Bird):
    def fly(self):
        print("Penguins can't fly, but they're excellent swimmers!")

def let_bird_fly(bird):
    bird.fly()

generic_bird = Bird()
sparrow = Sparrow()
penguin = Penguin()

print("Generic bird:")
let_bird_fly(generic_bird)

print("\nSparrow:")
let_bird_fly(sparrow)

print("\nPenguin:")
let_bird_fly(penguin)

#5.write a program to demonstrate encapsulation by creating a class BankAccount with private attributers balance and methods to de[posit,withdraw,and check balance.
class BankAccount:
    def __init__(self, initial_balance=0):

        self._balance = initial_balance

    def deposit(self, amount):
        """Add money to the account"""
        if amount > 0:
            self._balance += amount
            print(f"Deposited ₹{amount}. New balance: ₹{self._balance}")
        else:
            print("Deposit amount must be positive")

    def withdraw(self, amount):
        """Remove money from the account"""
        if amount > 0:
            if self._balance >= amount:
                self._balance -= amount
                print(f"Withdrew ₹{amount}. New balance: ₹{self._balance}")
            else:
                print("Insufficient funds")
        else:
            print("Withdrawal amount must be positive")

    def check_balance(self):
        """Return the current balance"""
        print(f"Current balance: ₹{self._balance}")
        return self._balance

account = BankAccount(1000)

account.check_balance()

account.deposit(500)
account.withdraw(200)
account.withdraw(1500)

print(account._balance)

account._balance = 5000
account.check_balance()

#6.demonstrate runtime polymorphism using a method play()in a base class instrument.derive classes guitar and piano that implement their own version of play().
class Instrument:
    def play(self):
        print("An instrument is playing...")

class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar strings: ♪ ♫ ♬")

class Piano(Instrument):
    def play(self):
        print("Pressing piano keys: ♩ ♪ ♫ ♬")

def play_instrument(instrument):
    instrument.play()

generic_instrument = Instrument()
my_guitar = Guitar()
my_piano = Piano()

print("Generic Instrument:")
play_instrument(generic_instrument)

print("\nGuitar:")
play_instrument(my_guitar)

print("\nPiano:")
play_instrument(my_piano)

print("\nOrchestra Performance:")
instruments = [Instrument(), Guitar(), Piano()]
for instrument in instruments:
    play_instrument(instrument)

#7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.
class MathOperations:

    @classmethod
    def add_numbers(cls, num1, num2):
        """Class method to add two numbers."""
        return num1 + num2

    @staticmethod
    def subtract_numbers(num1, num2):
        """Static method to subtract two numbers."""
        return num1 - num

sum_result = MathOperations.add_numbers(10, 5)
print(f"Addition result: {sum_result}")

diff_result = MathOperations.subtract_numbers(10, 5)
print(f"Subtraction result: {diff_result}")

#8.Implement a class Person with a class method to count the total number of persons created.
class Person:

    _total_persons = 0

    def __init__(self, name):
        self.name = name
        Person._total_persons += 1

    @classmethod
    def get_total_persons(cls):
        """Class method to return the total number of Person instances created."""
        return cls._total_persons

person1 = Person("Alice")
person2 = Person("Bob")
person3 = Person("Charlie")

print(f"Total persons created: {Person.get_total_persons()}")

#9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        """Override __str__ to display the fraction as 'numerator/denominator'."""
        return f"{self.numerator}/{self.denominator}"

frac1 = Fraction(3, 4)
frac2 = Fraction(5, 8)

print(frac1)
print(frac2)

#10.. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        if isinstance(other, Vector):
            return Vector(self.x + other.x, self.y + other.y)
        else:
            raise TypeError("Operands must be of type 'Vector'")

    def __str__(self):
        return f"Vector({self.x}, {self.y})"

v1 = Vector(2, 3)
v2 = Vector(5, 7)

v3 = v1 + v2

print(v1)
print(v2)
print(v3)

#11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

person1 = Person("Alice", 30)
person1.greet()

person2 = Person("Bob", 25)
person2.greet()

#12.Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.
class Student:
    def __init__(self, name, grades=None):
        self.name = name
        self.grades = grades if grades is not None else []

    def average_grade(self):
        """Calculate and return the average grade of the student."""
        if not self.grades:
            return 0.0
        return sum(self.grades) / len(self.grades)

student1 = Student("Alice", [85, 90, 78, 92])
print(f"{student1.name}'s average grade: {student1.average_grade():.2f}")

student2 = Student("Bob")
print(f"{student2.name}'s average grade: {student2.average_grade():.2f}")

#13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.
class Rectangle:
    def __init__(self, length=0, width=0):
        """Initialize rectangle with optional dimensions (default 0)"""
        self.length = length
        self.width = width

    def set_dimensions(self, length, width):
        """Set or update the rectangle's dimensions"""
        self.length = length
        self.width = width

    def area(self):
        """Calculate and return the area of the rectangle"""
        return self.length * self.width

rect = Rectangle()

rect.set_dimensions(5, 3)

print(f"Rectangle area: {rect.area()}")

rect.set_dimensions(7, 4)
print(f"Updated rectangle area: {rect.area()}")

#14.. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.
class Employee:
    def __init__(self, name, hourly_rate):
        self.name = name
        self.hourly_rate = hourly_rate

    def calculate_salary(self, hours_worked):
        """Calculate base salary from hours worked and hourly rate"""
        return hours_worked * self.hourly_rate

class Manager(Employee):
    def __init__(self, name, hourly_rate, bonus):
        super().__init__(name, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self, hours_worked):
        """Calculate salary including bonus"""
        base_salary = super().calculate_salary(hours_worked)
        return base_salary + self.bonus

regular_employee = Employee("John Doe", 20)
print(f"{regular_employee.name}'s salary: ${regular_employee.calculate_salary(40):.2f}")

manager = Manager("Jane Smith", 30, 1000)
print(f"{manager.name}'s salary: ${manager.calculate_salary(40):.2f}")

#15.. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        """Calculate the total price of the product (price × quantity)"""
        return self.price * self.quantit

product1 = Product("Laptop", 999.99, 2)
print(f"Total price for {product1.name}: ${product1.total_price():.2f}")

product2 = Product("Mouse", 24.50, 5)
print(f"Total price for {product2.name}: ${product2.total_price():.2f}")

#16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        """Abstract method that must be implemented by subclasses"""
        pass

class Cow(Animal):
    def sound(self):
        return "Moo!"

class Sheep(Animal):
    def sound(self):
        return "Baa!"

cow = Cow()
print(f"Cow says: {cow.sound()}")

sheep = Sheep()
print(f"Sheep says: {sheep.sound()}")


#17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        """Return a formatted string with the book's details"""
        return f"'{self.title}' by {self.author} ({self.year_published})"

book1 = Book("To Kill a Mockingbird", "Harper Lee", 1960)
print(book1.get_book_info())


book2 = Book("1984", "George Orwell", 1949)
print(book2.get_book_info())


#18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    def display_info(self):
        return f"Address: {self.address}, Price: ${self.price:,}"

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    def display_info(self):
        base_info = super().display_info()
        return f"{base_info}, Rooms: {self.number_of_rooms}"


regular_house = House("123 Main St", 350000)
print(regular_house.display_info())

luxury_mansion = Mansion("1 Beverly Hills", 25000000, 15)
print(luxury_mansion.display_info())
